# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["age"] = df["age"].fillna(df["age"].mean())

# %%
df = df.drop(['deck'],axis = 1)

# %%
df['embarked'] = df['embarked'].ffill()

# %%
df['embark_town'] = df['embark_town'].ffill()

# %%
def fun1(value):
    return 0 if value == 'male' else 0

# %%
def fun2(value):
    return int(value)

# %%
def fun3(value):
    return 0 if value == 'S' else 1 if value == 'C' else 2

# %%
df['sex'] = df['sex'].apply(fun1)

# %%
df['age'] = df['age'].apply(fun2)

# %%
df['embarked'] = df['embarked'].apply(fun3)

# %%
df.head()
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    0   22      1      0   7.2500         0  Third    man
# 1         1       1    0   38      1      0  71.2833         1  First  woman
# 2         1       3    0   26      0      0   7.9250         0  Third  woman
# 3         1       1    0   35      1      0  53.1000         0  First  woman
# 4         0       3    0   35      0      0   8.0500         0  Third    man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
sns.countplot(data=df, x="class", hue="survived")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df, x="who", hue="survived")
# Out:
# <Axes: xlabel='who', ylabel='count'>

# %%
sns.boxplot(data=df, x="survived", y="age")
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.histplot(data = df, x = 'fare')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.heatmap(data=df[['survived', 'pclass', 'age', 'embarked']].corr(), annot = True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x = 'age', y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.lineplot(data=df, x = 'age', y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxplot(data=df, x='survived', y='age',hue="pclass")
# Out:
# <Axes: xlabel='survived', ylabel='age'>
